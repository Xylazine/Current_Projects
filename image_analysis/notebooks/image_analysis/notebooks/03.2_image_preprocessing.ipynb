# %%
# pre-procesing steps
    # scale all images to a common frame of reference
    # strip skull
    # normalize tissue intensity based on histogram
    # z-score normalization of entire data set

# %%
# go through scan dictionary
# create new folder in local direcctory for each patient
# convert MRI image to numpy array
# resize images to a common dimension
# strip skull??
# histogram-based intensity adjustment
# z-score normalization
# save arrays to local folders
# create copy of dictionary with new path for image/mask arrays
